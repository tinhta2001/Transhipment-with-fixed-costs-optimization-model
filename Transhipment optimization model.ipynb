# %%
from pulp import *

# %%
#pip install pulp

# %%
#Indices
Mills = list(range(3))
Warehouses =  list(range(4))
Customer_areas = list(range(13))

#Parameters
Prod_max=[9900, 2100, 4200] #Production capacities
Prod_extra = [1100,1400,1500] #Extra capacities
Demand = [650,260,650,130,780,2500,910,3120,910,3640,1040,1650,1780] #Customer area demands
Transp_cost_1 = [[53, 95, 136, 160],
            [60, 120, 132, 140],
            [210, 190, 89, 71]] #Transportation costs from mills to warehouses
Transp_cost_2 = [[100, 120, 150, 160, 300, 310, 340, 490, 430,360, 280, 350, 200],
            [200, 240, 280, 310, 280, 400, 440, 410, 380, 190, 80, 150, 90],
            [280, 260, 320, 400, 140, 319, 290, 240, 230, 80, 60, 60, 160],
            [320, 280, 200, 130, 130, 70, 100, 90, 100, 190, 370, 320, 390]] #Transportation costs from warehouses to customers
Extra_cost = [300000,400000,450000] #Extra capacity costs

model = LpProblem("PP_MILP_model", LpMinimize) #Create a optimization model (minimization)
X=[[LpVariable("x_"+str(i)+str(k),0,None) for k in Warehouses] for i in Mills] #Create decision variables x_ik
Y=[[LpVariable("y_"+str(k)+str(j),0,None) for j in Customer_areas] for k in Warehouses] #Create decision variables y_kj
Z=[LpVariable("z_"+str(i),cat="Binary") for i in Mills ] #Create decision variables z_i

# %%
#Objective function
model += (lpSum([Transp_cost_1[i][k]*X[i][k] for i in Mills for k in Warehouses]) + lpSum([Transp_cost_2[k][j]*Y[k][j] for k in Warehouses for j in Customer_areas]) + lpSum([Extra_cost[i]*Z[i] for i in Mills]), "Testing_objective_function")

# %%
#TODO: add objective function and constraints here after back from Alps!:
#Cacpacity constraints at the mills (1)
for i in Mills:
    model += (lpSum([X[i][k] for k in Warehouses]) <= Prod_max[i] + Z[i] * Prod_extra[i], "Capacity at mill " + str(i+1))

# %%
#Demand constraint (3)
for j in Customer_areas: 
    model += (lpSum([Y[k][j] for k in Warehouses]) == Demand[j], "Demand at customer area " + str(j+1))

# %%
#Total transported from mills to warehouse has to be equal to total transported from warehouse to customer area
for k in Warehouses:
    model += (lpSum([X[i][k] for i in Mills]) == (lpSum([Y[k][j] for j in Customer_areas ])), "Total transported from warehouse " + str(k+1) + " to customer areas is equal to total product received from production Mills")

# %%
model.solve() #Solve the optimal solution to model

#Print optimal objective function value:
print("Optimal total cost "+str(model.objective.value())+" .")
   
                     
#Print optimal decision variable values: 
for i in Mills:
    print("------")
    if (Z[i].varValue==1):
        print("Purchase extra capacity for mill "+str(i+1)) 
    for k in Warehouses:
        if (X[i][k].varValue>0):
            print("Transport "+str(X[i][k].varValue)+" tons from mill "+str(i+1)+" to warehouse "+str(k+1)+".") 
    

print("---------------")
for k in Warehouses:
    for j in Customer_areas: 
        if (Y[k][j].varValue>0):
            print("Transport "+str(Y[k][j].varValue)+" tons from warehouse "+str(k+1)+" to customer area "+str(j+1)+".") 
    print("---")
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /opt/software/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d55e0321aae0462cb7cc86de1a6c0267-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/d55e0321aae0462cb7cc86de1a6c0267-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 25 COLUMNS
# At line 230 RHS
# At line 251 BOUNDS
# At line 255 ENDATA
# Problem MODEL has 20 rows, 67 columns and 131 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 3.9615e+06 - 0.00 seconds
# Cgl0004I processed model has 20 rows, 67 columns (3 integer (3 of which binary)) and 131 elements
# Cbc0038I Initial state - 1 integers unsatisfied sum - 0.290909
# Cbc0038I Pass   1: suminf.    0.22857 (1) obj. 3.96374e+06 iterations 1
# Cbc0038I Solution found of 4.27231e+06
# Cbc0038I Relaxing continuous gives 4.26779e+06
# Cbc0038I Before mini branch and bound, 1 integers at bound fixed and 57 continuous
# Cbc0038I Full problem 20 rows 67 columns, reduced to 2 rows 3 columns
# Cbc0038I Mini branch and bound improved solution from 4.26779e+06 to 4.17423e+06 (0.00 seconds)
# Cbc0038I Round again with cutoff of 4.15296e+06
# Cbc0038I Pass   2: suminf.    0.22857 (1) obj. 3.96374e+06 iterations 0
# Cbc0038I Pass   3: suminf.    0.29116 (1) obj. 4.15296e+06 iterations 4
# Cbc0038I Pass   4: suminf.    0.28000 (1) obj. 4.15296e+06 iterations 2
# Cbc0038I Pass   5: suminf.    0.29116 (1) obj. 4.15296e+06 iterations 2
# Cbc0038I Pass   6: suminf.    0.29116 (1) obj. 4.15296e+06 iterations 0
# Cbc0038I Pass   7: suminf.    0.29116 (1) obj. 4.15296e+06 iterations 0
# Cbc0038I Pass   8: suminf.    0.29116 (1) obj. 4.15296e+06 iterations 0
# Cbc0038I Pass   9: suminf.    0.29116 (1) obj. 4.15296e+06 iterations 0
# Cbc0038I Pass  10: suminf.    0.29116 (1) obj. 4.15296e+06 iterations 0
# Cbc0038I Pass  11: suminf.    0.29116 (1) obj. 4.15296e+06 iterations 0
# Cbc0038I Pass  12: suminf.    0.06303 (1) obj. 4.15296e+06 iterations 3
# Cbc0038I Pass  13: suminf.    0.06303 (1) obj. 4.15296e+06 iterations 0
# Cbc0038I Pass  14: suminf.    0.48000 (1) obj. 4.00461e+06 iterations 2
# Cbc0038I Pass  15: suminf.    0.48000 (1) obj. 4.00461e+06 iterations 0
# Cbc0038I Pass  16: suminf.    0.28000 (1) obj. 4.02283e+06 iterations 6
# Cbc0038I Pass  17: suminf.    0.28000 (1) obj. 4.02283e+06 iterations 0
# Cbc0038I Pass  18: suminf.    0.28000 (1) obj. 4.02283e+06 iterations 0
# Cbc0038I Pass  19: suminf.    0.22857 (1) obj. 3.96374e+06 iterations 1
# Cbc0038I Pass  20: suminf.    0.22857 (1) obj. 3.96374e+06 iterations 0
# Cbc0038I Pass  21: suminf.    0.22857 (1) obj. 3.96374e+06 iterations 0
# Cbc0038I Pass  22: suminf.    0.22857 (1) obj. 3.96374e+06 iterations 0
# Cbc0038I Pass  23: suminf.    0.29116 (1) obj. 4.15296e+06 iterations 4
# Cbc0038I Pass  24: suminf.    0.29116 (1) obj. 4.15296e+06 iterations 0
# Cbc0038I Pass  25: suminf.    0.19283 (1) obj. 4.15296e+06 iterations 5
# Cbc0038I Pass  26: suminf.    0.19283 (1) obj. 4.15296e+06 iterations 0
# Cbc0038I Pass  27: suminf.    0.19283 (1) obj. 4.15296e+06 iterations 0
# Cbc0038I Pass  28: suminf.    0.19283 (1) obj. 4.15296e+06 iterations 0
# Cbc0038I Pass  29: suminf.    0.19283 (1) obj. 4.15296e+06 iterations 0
# Cbc0038I Pass  30: suminf.    0.19283 (1) obj. 4.15296e+06 iterations 0
# Cbc0038I Pass  31: suminf.    0.19283 (1) obj. 4.15296e+06 iterations 0
# Cbc0038I No solution found this major pass
# Cbc0038I Before mini branch and bound, 0 integers at bound fixed and 53 continuous
# Cbc0038I Full problem 20 rows 67 columns, reduced to 4 rows 9 columns
# Cbc0038I Mini branch and bound did not improve solution (0.01 seconds)
# Cbc0038I After 0.01 seconds - Feasibility pump exiting with objective of 4.17423e+06 - took 0.00 seconds
# Cbc0012I Integer solution of 4174230 found by feasibility pump after 0 iterations and 0 nodes (0.01 seconds)
# Cbc0038I Full problem 20 rows 67 columns, reduced to 20 rows 65 columns
# Cbc0031I 1 added rows had average density of 3
# Cbc0013I At root node, 8 cuts changed objective from 3961502.7 to 4228330 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 4 row cuts average 2.8 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 2 row cuts average 8.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 1 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 3 row cuts average 2.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 4174230, took 5 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 3.9615e+06 to 4.22833e+06
# Probing was tried 2 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 2 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 2 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                4174230.00000000
# Enumerated nodes:               0
# Total iterations:               5
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Optimal total cost 4174230.0 .
# ------
# Purchase extra capacity for mill 1
# Transport 1690.0 tons from mill 1 to warehouse 1.
# Transport 2820.0 tons from mill 1 to warehouse 2.
# Transport 5710.0 tons from mill 1 to warehouse 3.
# ------
# Transport 2100.0 tons from mill 2 to warehouse 4.
# ------
# Purchase extra capacity for mill 3
# Transport 5700.0 tons from mill 3 to warehouse 4.
# ---------------
# Transport 650.0 tons from warehouse 1 to customer area 1.
# Transport 260.0 tons from warehouse 1 to customer area 2.
# Transport 650.0 tons from warehouse 1 to customer area 3.
# Transport 130.0 tons from warehouse 1 to customer area 4.
# ---
# Transport 1040.0 tons from warehouse 2 to customer area 11.
# Transport 1780.0 tons from warehouse 2 to customer area 13.
# ---
# Transport 420.0 tons from warehouse 3 to customer area 5.
# Transport 3640.0 tons from warehouse 3 to customer area 10.
# Transport 1650.0 tons from warehouse 3 to customer area 12.
# ---
# Transport 360.0 tons from warehouse 4 to customer area 5.
# Transport 2500.0 tons from warehouse 4 to customer area 6.
# Transport 910.0 tons from warehouse 4 to customer area 7.
# Transport 3120.0 tons from warehouse 4 to customer area 8.
# Transport 910.0 tons from warehouse 4 to customer area 9.
# ---

# %%
model
# Out:
# PP_MILP_model:
# MINIMIZE
# 53*x_00 + 95*x_01 + 136*x_02 + 160*x_03 + 60*x_10 + 120*x_11 + 132*x_12 + 140*x_13 + 210*x_20 + 190*x_21 + 89*x_22 + 71*x_23 + 100*y_00 + 120*y_01 + 280*y_010 + 350*y_011 + 200*y_012 + 150*y_02 + 160*y_03 + 300*y_04 + 310*y_05 + 340*y_06 + 490*y_07 + 430*y_08 + 360*y_09 + 200*y_10 + 240*y_11 + 80*y_110 + 150*y_111 + 90*y_112 + 280*y_12 + 310*y_13 + 280*y_14 + 400*y_15 + 440*y_16 + 410*y_17 + 380*y_18 + 190*y_19 + 280*y_20 + 260*y_21 + 60*y_210 + 60*y_211 + 160*y_212 + 320*y_22 + 400*y_23 + 140*y_24 + 319*y_25 + 290*y_26 + 240*y_27 + 230*y_28 + 80*y_29 + 320*y_30 + 280*y_31 + 370*y_310 + 320*y_311 + 390*y_312 + 200*y_32 + 130*y_33 + 130*y_34 + 70*y_35 + 100*y_36 + 90*y_37 + 100*y_38 + 190*y_39 + 300000*z_0 + 400000*z_1 + 450000*z_2 + 0
# SUBJECT TO
# Capacity_at_mill_1: x_00 + x_01 + x_02 + x_03 - 1100 z_0 <= 9900
#
# Capacity_at_mill_2: x_10 + x_11 + x_12 + x_13 - 1400 z_1 <= 2100
#
# Capacity_at_mill_3: x_20 + x_21 + x_22 + x_23 - 1500 z_2 <= 4200
#
# Demand_at_customer_area_1: y_00 + y_10 + y_20 + y_30 = 650
#
# Demand_at_customer_area_2: y_01 + y_11 + y_21 + y_31 = 260
#
# Demand_at_customer_area_3: y_02 + y_12 + y_22 + y_32 = 650
#
# Demand_at_customer_area_4: y_03 + y_13 + y_23 + y_33 = 130
#
# Demand_at_customer_area_5: y_04 + y_14 + y_24 + y_34 = 780
#
# Demand_at_customer_area_6: y_05 + y_15 + y_25 + y_35 = 2500
#
# Demand_at_customer_area_7: y_06 + y_16 + y_26 + y_36 = 910
#
# Demand_at_customer_area_8: y_07 + y_17 + y_27 + y_37 = 3120
#
# Demand_at_customer_area_9: y_08 + y_18 + y_28 + y_38 = 910
#
# Demand_at_customer_area_10: y_09 + y_19 + y_29 + y_39 = 3640
#
# Demand_at_customer_area_11: y_010 + y_110 + y_210 + y_310 = 1040
#
# Demand_at_customer_area_12: y_011 + y_111 + y_211 + y_311 = 1650
#
# Demand_at_customer_area_13: y_012 + y_112 + y_212 + y_312 = 1780
#
# Total_transported_from_warehouse_1_to_customer_areas_is_equal_to_total_product_received_from_production_Mills:
#  x_00 + x_10 + x_20 - y_00 - y_01 - y_010 - y_011 - y_012 - y_02 - y_03 - y_04
#  - y_05 - y_06 - y_07 - y_08 - y_09 = 0
#
# Total_transported_from_warehouse_2_to_customer_areas_is_equal_to_total_product_received_from_production_Mills:
#  x_01 + x_11 + x_21 - y_10 - y_11 - y_110 - y_111 - y_112 - y_12 - y_13 - y_14
#  - y_15 - y_16 - y_17 - y_18 - y_19 = 0
#
# Total_transported_from_warehouse_3_to_customer_areas_is_equal_to_total_product_received_from_production_Mills:
#  x_02 + x_12 + x_22 - y_20 - y_21 - y_210 - y_211 - y_212 - y_22 - y_23 - y_24
#  - y_25 - y_26 - y_27 - y_28 - y_29 = 0
#
# Total_transported_from_warehouse_4_to_customer_areas_is_equal_to_total_product_received_from_production_Mills:
#  x_03 + x_13 + x_23 - y_30 - y_31 - y_310 - y_311 - y_312 - y_32 - y_33 - y_34
#  - y_35 - y_36 - y_37 - y_38 - y_39 = 0
#
# VARIABLES
# x_00 Continuous
# x_01 Continuous
# x_02 Continuous
# x_03 Continuous
# x_10 Continuous
# x_11 Continuous
# x_12 Continuous
# x_13 Continuous
# x_20 Continuous
# x_21 Continuous
# x_22 Continuous
# x_23 Continuous
# y_00 Continuous
# y_01 Continuous
# y_010 Continuous
# y_011 Continuous
# y_012 Continuous
# y_02 Continuous
# y_03 Continuous
# y_04 Continuous
# y_05 Continuous
# y_06 Continuous
# y_07 Continuous
# y_08 Continuous
# y_09 Continuous
# y_10 Continuous
# y_11 Continuous
# y_110 Continuous
# y_111 Continuous
# y_112 Continuous
# y_12 Continuous
# y_13 Continuous
# y_14 Continuous
# y_15 Continuous
# y_16 Continuous
# y_17 Continuous
# y_18 Continuous
# y_19 Continuous
# y_20 Continuous
# y_21 Continuous
# y_210 Continuous
# y_211 Continuous
# y_212 Continuous
# y_22 Continuous
# y_23 Continuous
# y_24 Continuous
# y_25 Continuous
# y_26 Continuous
# y_27 Continuous
# y_28 Continuous
# y_29 Continuous
# y_30 Continuous
# y_31 Continuous
# y_310 Continuous
# y_311 Continuous
# y_312 Continuous
# y_32 Continuous
# y_33 Continuous
# y_34 Continuous
# y_35 Continuous
# y_36 Continuous
# y_37 Continuous
# y_38 Continuous
# y_39 Continuous
# 0 <= z_0 <= 1 Integer
# 0 <= z_1 <= 1 Integer
# 0 <= z_2 <= 1 Integer
